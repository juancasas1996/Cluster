# %%
# !pip install sentence-transformers
# !pip install scikit-learn
# !pip install ipykernel
# !pip install pandas

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans

# %%
# Cargar el modelo SentenceTransformer
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# Downloading (…)0fe39/.gitattributes: 100%|██████████| 968/968 [00:00<00:00, 265kB/s]
# Downloading (…)_Pooling/config.json: 100%|██████████| 190/190 [00:00<00:00, 289kB/s]
# Downloading (…)83e900fe39/README.md: 100%|██████████| 3.79k/3.79k [00:00<00:00, 6.56MB/s]
# Downloading (…)e900fe39/config.json: 100%|██████████| 645/645 [00:00<00:00, 1.42MB/s]
# Downloading (…)ce_transformers.json: 100%|██████████| 122/122 [00:00<00:00, 187kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 471M/471M [00:47<00:00, 9.82MB/s]
# Downloading (…)nce_bert_config.json: 100%|██████████| 53.0/53.0 [00:00<00:00, 101kB/s]
# Downloading (…)tencepiece.bpe.model: 100%|██████████| 5.07M/5.07M [00:00<00:00, 8.39MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 239/239 [00:00<00:00, 553kB/s]
# Downloading tokenizer.json: 100%|██████████| 9.08M/9.08M [00:00<00:00, 15.0MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 480/480 [00:00<00:00, 1.16MB/s]
# Downloading unigram.json: 100%|██████████| 14.8M/14.8M [00:01<00:00, 13.6MB/s]
# Downloading (…)900fe39/modules.json: 100%|██████████| 229/229 [00:00<00:00, 577kB/s]

# %%
# Ejemplo de frases en español
frases = [
    'La programación es una habilidad clave en el mundo laboral actual.',
    'El trabajo en equipo es fundamental en el desarrollo de proyectos de programación.',
    'La industria tecnológica ofrece numerosas oportunidades laborales en el campo de la programación.',
    'La programación es una forma creativa de resolver problemas.',
    'La actualización constante de habilidades es esencial en el ámbito de la programación.',
    'La práctica regular de deporte mejora la salud física y mental.',
    'Una alimentación balanceada es fundamental para mantener una buena salud.',
    'El deporte ayuda a reducir el estrés y mejorar el estado de ánimo.',
    'La salud es un tesoro que debemos cuidar y valorar.',
    'El deporte es una actividad divertida que nos permite mantenernos en forma.',
    'Amo a mi perro con toda mi vida',
    'Mi mascota es lo mejor que me ha sucedido'

]

# %%
# Crear el DataFrame
df = pd.DataFrame({'frases': frases})

# Obtener las representaciones de las frases
embeddings = model.encode(df['frases'].tolist())

# Convertir las representaciones en un DataFrame
embeddings_df = pd.DataFrame(embeddings)

# Concatenar el DataFrame original con las representaciones
df_concatenated = pd.concat([df, embeddings_df], axis=1)

# Imprimir el DataFrame con las representaciones concatenadas
df_concatenated.head()
# Out:
#                                               frases         0         1  \
# 0  La programación es una habilidad clave en el m... -0.213440 -0.069173
# 1  El trabajo en equipo es fundamental en el desa... -0.196377 -0.179967
# 2  La industria tecnológica ofrece numerosas opor...  0.119977 -0.034705
# 3  La programación es una forma creativa de resol... -0.166526 -0.126639
# 4  La actualización constante de habilidades es e... -0.204488  0.074458
#
#           2         3         4         5         6         7         8  ...  \
# 0 -0.197310 -0.029537 -0.130899  0.094700 -0.013937 -0.065586 -0.128986  ...
# 1 -0.068353 -0.064427 -0.267967 -0.021664 -0.277520 -0.026893  0.128443  ...
# 2  0.030453 -0.028797 -0.165328  0.196111 -0.215492  0.162536 -0.116884  ...
# 3  0.018844  0.074610 -0.300953 -0.451533  0.019474  0.066848 -0.125206  ...
# 4 -0.085291 -0.193263 -0.080821  0.252467 -0.029595 -0.026288 -0.155235  ...
#
#         374       375       376       377       378       379       380  \
# 0 -0.011848  0.112096  0.110057 -0.194281  0.122164  0.201293 -0.263372
# 1  0.265531  0.452463  0.059066 -0.019282  0.238384 -0.043932 -0.224611
# 2 -0.099785  0.158787 -0.017309 -0.005480  0.185993  0.076208 -0.190564
# 3  0.374178 -0.030013 -0.066812  0.165862  0.018059  0.252715 -0.445652
# 4 -0.177928  0.108788  0.006891  0.098997  0.174441  0.074593 -0.151156
#
#         381       382       383
# 0  0.073772  0.209616 -0.065574
# 1  0.203272  0.220722 -0.301896
# 2 -0.260236  0.398519 -0.220524
# 3  0.429021  0.188208 -0.156397
# 4  0.185951  0.062185 -0.001365
#
# [5 rows x 385 columns]

# %%
# Aplicar el algoritmo K-means
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(embeddings)

# Agregar los clusters al DataFrame
df['cluster'] = clusters

# Imprimir el DataFrame con los clusters
df.head(12)
# Out:
# /opt/anaconda3/envs/clus/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /opt/anaconda3/envs/clus/lib/python3.10/site-packages/threadpoolctl.py:1010: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
#                                                frases  cluster
# 0   La programación es una habilidad clave en el m...        0
# 1   El trabajo en equipo es fundamental en el desa...        0
# 2   La industria tecnológica ofrece numerosas opor...        0
# 3   La programación es una forma creativa de resol...        0
# 4   La actualización constante de habilidades es e...        0
# 5   La práctica regular de deporte mejora la salud...        1
# 6   Una alimentación balanceada es fundamental par...        1
# 7   El deporte ayuda a reducir el estrés y mejorar...        1
# 8   La salud es un tesoro que debemos cuidar y val...        1
# 9   El deporte es una actividad divertida que nos ...        1
# 10                    Amo a mi perro con toda mi vida        2
# 11          Mi mascota es lo mejor que me ha sucedido        2

# %%
frases = [
    'La programación es una habilidad clave en el mundo laboral actual.',
    'La práctica regular de deporte mejora la salud física y mental.',
    'El trabajo en equipo es fundamental en el desarrollo de proyectos de programación.',
    'Una alimentación balanceada es fundamental para mantener una buena salud.',
    'La industria tecnológica ofrece numerosas oportunidades laborales en el campo de la programación.',
    'El deporte ayuda a reducir el estrés y mejorar el estado de ánimo.',
    'La programación es una forma creativa de resolver problemas.',
    'La salud es un tesoro que debemos cuidar y valorar.',
    'La actualización constante de habilidades es esencial en el ámbito de la programación.',
    'El deporte es una actividad divertida que nos permite mantenernos en forma.'
]

# Crear el DataFrame
df = pd.DataFrame({'frases': frases})

# Obtener las representaciones de las frases
embeddings = model.encode(df['frases'].tolist())

# Convertir las representaciones en un DataFrame
embeddings_df = pd.DataFrame(embeddings)

# Concatenar el DataFrame original con las representaciones
df_concatenated = pd.concat([df, embeddings_df], axis=1)

# Aplicar el algoritmo K-means
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(embeddings)

# Agregar los clusters al DataFrame
df['cluster'] = clusters

# Imprimir el DataFrame con los clusters
df.head(10)
# Out:
# /opt/anaconda3/envs/clus/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                               frases  cluster
# 0  La programación es una habilidad clave en el m...        1
# 1  La práctica regular de deporte mejora la salud...        0
# 2  El trabajo en equipo es fundamental en el desa...        1
# 3  Una alimentación balanceada es fundamental par...        0
# 4  La industria tecnológica ofrece numerosas opor...        1
# 5  El deporte ayuda a reducir el estrés y mejorar...        0
# 6  La programación es una forma creativa de resol...        1
# 7  La salud es un tesoro que debemos cuidar y val...        0
# 8  La actualización constante de habilidades es e...        1
# 9  El deporte es una actividad divertida que nos ...        0
